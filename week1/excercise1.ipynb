# %% [markdown]
# ## number c

# %%
def SumDigits(n):
    number_str = str(n)
    add= sum(int(digit) for digit in number_str)
    return add
print(SumDigits(325))
# Out:
# 10

# %% [markdown]
# ### number d

# %%
def squaredSum(number):
    square = number **2
    sum_squared_num= sum(map(square,number))

print(squaredSum[2,3,4])
# Out:
#   Cell In[5], line 1
#     def squaredSum([number]):
#                    ^
# SyntaxError: invalid syntax
